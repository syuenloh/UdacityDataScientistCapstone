# %% [markdown]
# # Starbucks Capstone Challenge
#
# ### Introduction
#
# This data set contains simulated data that mimics customer behavior on the Starbucks rewards mobile app. Once every few days, Starbucks sends out an offer to users of the mobile app. An offer can be merely an advertisement for a drink or an actual offer such as a discount or BOGO (buy one get one free). Some users might not receive any offer during certain weeks.
#
# Not all users receive the same offer, and that is the challenge to solve with this data set.
#
# Your task is to combine transaction, demographic and offer data to determine which demographic groups respond best to which offer type. This data set is a simplified version of the real Starbucks app because the underlying simulator only has one product whereas Starbucks actually sells dozens of products.
#
# Every offer has a validity period before the offer expires. As an example, a BOGO offer might be valid for only 5 days. You'll see in the data set that informational offers have a validity period even though these ads are merely providing information about a product; for example, if an informational offer has 7 days of validity, you can assume the customer is feeling the influence of the offer for 7 days after receiving the advertisement.
#
# You'll be given transactional data showing user purchases made on the app including the timestamp of purchase and the amount of money spent on a purchase. This transactional data also has a record for each offer that a user receives as well as a record for when a user actually views the offer. There are also records for when a user completes an offer.
#
# Keep in mind as well that someone using the app might make a purchase through the app without having received an offer or seen an offer.
#
# ### Example
#
# To give an example, a user could receive a discount offer buy 10 dollars get 2 off on Monday. The offer is valid for 10 days from receipt. If the customer accumulates at least 10 dollars in purchases during the validity period, the customer completes the offer.
#
# However, there are a few things to watch out for in this data set. Customers do not opt into the offers that they receive; in other words, a user can receive an offer, never actually view the offer, and still complete the offer. For example, a user might receive the "buy 10 dollars get 2 dollars off offer", but the user never opens the offer during the 10 day validity period. The customer spends 15 dollars during those ten days. There will be an offer completion record in the data set; however, the customer was not influenced by the offer because the customer never viewed the offer.
#
# ### Cleaning
#
# This makes data cleaning especially important and tricky.
#
# You'll also want to take into account that some demographic groups will make purchases even if they don't receive an offer. From a business perspective, if a customer is going to make a 10 dollar purchase without an offer anyway, you wouldn't want to send a buy 10 dollars get 2 dollars off offer. You'll want to try to assess what a certain demographic group will buy when not receiving any offers.
#
# ### Final Advice
#
# Because this is a capstone project, you are free to analyze the data any way you see fit. For example, you could build a machine learning model that predicts how much someone will spend based on demographics and offer type. Or you could build a model that predicts whether or not someone will respond to an offer. Or, you don't need to build a machine learning model at all. You could develop a set of heuristics that determine what offer you should send to each customer (ie 75 percent of women customers who were 35 years old responded to offer A vs 40 percent from the same demographic to offer B, so send offer A).

# %% [markdown]
# # Data Sets
#
# The data is contained in three files:
#
# * portfolio.json - containing offer ids and meta data about each offer (duration, type, etc.)
# * profile.json - demographic data for each customer
# * transcript.json - records for transactions, offers received, offers viewed, and offers completed
#
# Here is the schema and explanation of each variable in the files:
#
# **portfolio.json**
# * id (string) - offer id
# * offer_type (string) - type of offer ie BOGO, discount, informational
# * difficulty (int) - minimum required spend to complete an offer
# * reward (int) - reward given for completing an offer
# * duration (int) -
# * channels (list of strings)
#
# **profile.json**
# * age (int) - age of the customer
# * became_member_on (int) - date when customer created an app account
# * gender (str) - gender of the customer (note some entries contain 'O' for other rather than M or F)
# * id (str) - customer id
# * income (float) - customer's income
#
# **transcript.json**
# * event (str) - record description (ie transaction, offer received, offer viewed, etc.)
# * person (str) - customer id
# * time (int) - time in hours. The data begins at time t=0
# * value - (dict of strings) - either an offer id or transaction amount depending on the record
#
# **Note:** If you are using the workspace, you will need to go to the terminal and run the command `conda update pandas` before reading in the files. This is because the version of pandas in the workspace cannot read in the transcript.json file correctly, but the newest version of pandas can. You can access the termnal from the orange icon in the top left of this notebook.
#
# You can see how to access the terminal and how the install works using the two images below.  First you need to access the terminal:
#
# <img src="pic1.png"/>
#
# Then you will want to run the above command:
#
# <img src="pic2.png"/>
#
# Finally, when you enter back into the notebook (use the jupyter icon again), you should be able to run the below cell without any errors.

# %%
import pandas as pd
import numpy as np
import math
import json
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn import svm
from time import time
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import AdaBoostClassifier
#from xgboost import XGBClassifier
# %matplotlib inline

# read in the json files
portfolio = pd.read_json('portfolio.json', orient='records', lines=True)
profile = pd.read_json('profile.json', orient='records', lines=True)
# transcript = pd.read_json('transcript.json', orient='records', lines=True)
transcript=pd.read_csv('transcript_expanded.csv')

# %% [markdown]
# Data Exploration

# %%
portfolio['offer_type'].unique()
# Out:
# array(['bogo', 'informational', 'discount'], dtype=object)

# %%
portfolio.head()
# Out:
#                        channels  difficulty  duration  \
# 0       [email, mobile, social]          10         7
# 1  [web, email, mobile, social]          10         5
# 2          [web, email, mobile]           0         4
# 3          [web, email, mobile]           5         7
# 4                  [web, email]          20        10
#
#                                  id     offer_type  reward
# 0  ae264e3637204a6fb9bb56bc8210ddfd           bogo      10
# 1  4d5c57ea9a6940dd891ad53e9dbe8da0           bogo      10
# 2  3f207df678b143eea3cee63160fa8bed  informational       0
# 3  9b98b8c7a33c4b65b9aebfe6a799e6d9           bogo       5
# 4  0b1e1539f2cc45b7b9fa7c272da2e1d7       discount       5

# %%
profile.head()
# Out:
#    age  became_member_on gender                                id    income
# 0  118          20170212   None  68be06ca386d4c31939f3a4f0e3dd783       NaN
# 1   55          20170715      F  0610b486422d4921ae7d2bf64640c50b  112000.0
# 2  118          20180712   None  38fe809add3b4fcf9315a9694bb96ff5       NaN
# 3   75          20170509      F  78afa995795e4d85b5d9ceeca43f5fef  100000.0
# 4  118          20170804   None  a03223e636434f42ac4c3df47e8bac43       NaN

# %% [markdown]
# Data Cleaning
# 1. extract different values from transcript into different columns.
# 2. offer_id into offer id

# %%
#expand value column in transcript
# transcript=pd.concat([transcript, transcript['value'].apply(pd.Series)], axis=1)
# transcript.to_csv('transcript_expanded.csv',index=False)

transcript=pd.read_csv('transcript_expanded.csv')

# %%
#create new column to ensure only one offer_id column
transcript['offer_id_new']=np.where(transcript['offer id'].isnull() & transcript['offer_id'].notnull(),transcript['offer_id'],transcript['offer id'])

#drop unnecessary offer_id columns
transcript.drop(['offer id','offer_id'],axis=1,inplace=True)

#rename offer_id column
transcript.rename(columns={'offer_id_new':'offer_id'},inplace=True)

# %%
portfolio.rename(columns={'id':'offer_id'},inplace=True)

# %%
transcript=transcript.merge(portfolio,how='left',on='offer_id')

# %%
transcript['day_offer']=transcript['time']/24

# %%
transcript=transcript.sort_values(['person','day_offer'])

# %%
def drop_cols(drop_cols,df):
    df.drop(drop_cols,axis=1,inplace=True)
    return df

# %%
drop_cols(['value','time','reward_y'],transcript);

# %%
transcript.loc[transcript['event']=='offer received','sequence']=0
transcript.loc[transcript['event']=='offer viewed','sequence']=1
transcript.loc[transcript['event']=='transaction','sequence']=2
transcript.loc[transcript['event']=='offer completed','sequence']=3

# %%
offers_view_transacted2=transcript[['day_offer','offer_id','person','event']][(transcript['event']=='transaction') | (transcript['event']=='offer viewed')].ffill()

# %%
transactions_clean=transcript.merge(offers_view_transacted2,how='left',on=['person','day_offer','event'])

# %%
transactions_clean['offer_id']=np.where(transactions_clean['offer_id_x'].isnull(),transactions_clean['offer_id_y'],transactions_clean['offer_id_x'])

drop_cols(['offer_id_x','offer_id_y'],transactions_clean);

# %%
transactions_clean=transactions_clean.merge(portfolio,how='left',on='offer_id')

# %%
transactions_clean.columns
# Out:
# Index(['event', 'person', 'amount', 'reward', 'day_offer', 'sequence',
#        'offer_id', 'channels', 'difficulty', 'offer_type', 'reward',
#        'duration', 'event_1', 'offer_id_previous'],
#       dtype='object')

# %%
transactions_clean['duration']=np.where(transactions_clean['duration_x'].isnull(),transactions_clean['duration_y'],transactions_clean['duration_x'])

# %%
drop_cols(['duration_x','offer_type_x','difficulty_x','channels_x','duration_y'],transactions_clean);

# %%
transactions_clean.rename(columns={'channels_y':'channels','reward_x':'reward','difficulty_y':'difficulty','offer_type_y':'offer_type'},inplace=True)

# %%
offers_viewed_transactions_completed=transactions_clean[(transactions_clean['event']=='offer viewed') | (transactions_clean['event']=='transaction') | (transactions_clean['event']=='offer completed')].copy()

# %%
offers_received=transactions_clean[transactions_clean['event']=='offer received'].copy()

# %%
offers_viewed_transactions_completed['offer_id_previous'] = offers_viewed_transactions_completed.groupby(['person','offer_id'])['offer_id'].shift()

# %%
offers_viewed_transactions_completed['valid_completed']=np.where(offers_viewed_transactions_completed['offer_id_previous']==offers_viewed_transactions_completed['offer_id'],1,0)

# %%
offers_viewed_transactions_completed.columns
# Out:
# Index(['event', 'person', 'amount', 'reward', 'day_offer', 'sequence',
#        'offer_id', 'channels', 'difficulty', 'offer_type', 'reward',
#        'duration', 'offer_id_previous', 'valid_completed'],
#       dtype='object')

# %%
offers_received.columns
# Out:
# Index(['event', 'person', 'amount', 'reward', 'day_offer', 'sequence',
#        'offer_id', 'channels', 'difficulty', 'offer_type', 'reward',
#        'duration'],
#       dtype='object')

# %%
offers_received['offer_id_previous']=np.nan
offers_received['valid_completed']=np.nan

# %%
transactions_clean2=offers_received.append(offers_viewed_transactions_completed)

# %%
transactions_clean2=transactions_clean2.sort_values(['person','day_offer','event','offer_id'])

# %%
transactions_clean2['diff_info']=transactions_clean2[(transactions_clean2['offer_type']=='informational') & ((transactions_clean2['event']=='offer received') | (transactions_clean2['event']=='transaction'))].groupby(['person','offer_id'])['day_offer'].diff()

# %%
transactions_clean2['diff_bogo']=transactions_clean2[(transactions_clean2['offer_type']=='bogo') & ((transactions_clean2['event']=='offer received') | (transactions_clean2['event']=='offer completed'))].groupby(['person','offer_id'])['day_offer'].diff()

# %%
transactions_clean2['diff_discount']=transactions_clean2[(transactions_clean2['offer_type']=='discount') & ((transactions_clean2['event']=='offer received') | (transactions_clean2['event']=='offer completed'))].groupby(['person','offer_id'])['day_offer'].diff()

# %%
transactions_clean2['valid_completed_duration']=np.nan

# %%
transactions_clean2.loc[transactions_clean2['diff_info']<=transactions_clean2['duration'],'valid_completed_duration']=1
transactions_clean2.loc[transactions_clean2['diff_discount']<=transactions_clean2['duration'],'valid_completed_duration']=1
transactions_clean2.loc[transactions_clean2['diff_bogo']<=transactions_clean2['duration'],'valid_completed_duration']=1

# %%
transactions_clean2
# Out:
#                   event                            person  amount  reward  \
# 0        offer received  0009655768c64bdeb2e877511632db8f     NaN     NaN
# 1          offer viewed  0009655768c64bdeb2e877511632db8f     NaN     NaN
# 2           transaction  0009655768c64bdeb2e877511632db8f   22.16     NaN
# 3        offer received  0009655768c64bdeb2e877511632db8f     NaN     NaN
# 4          offer viewed  0009655768c64bdeb2e877511632db8f     NaN     NaN
# 5        offer received  0009655768c64bdeb2e877511632db8f     NaN     NaN
# 7       offer completed  0009655768c64bdeb2e877511632db8f     NaN     5.0
# 6           transaction  0009655768c64bdeb2e877511632db8f    8.57     NaN
# 8          offer viewed  0009655768c64bdeb2e877511632db8f     NaN     NaN
# 9        offer received  0009655768c64bdeb2e877511632db8f     NaN     NaN
# 11      offer completed  0009655768c64bdeb2e877511632db8f     NaN     2.0
# 10          transaction  0009655768c64bdeb2e877511632db8f   14.11     NaN
# 12         offer viewed  0009655768c64bdeb2e877511632db8f     NaN     NaN
# 13          transaction  0009655768c64bdeb2e877511632db8f   13.56     NaN
# 16      offer completed  0009655768c64bdeb2e877511632db8f     NaN     2.0
# 14       offer received  0009655768c64bdeb2e877511632db8f     NaN     NaN
# 15          transaction  0009655768c64bdeb2e877511632db8f   10.27     NaN
# 17          transaction  0009655768c64bdeb2e877511632db8f   12.36     NaN
# 18          transaction  0009655768c64bdeb2e877511632db8f   28.16     NaN
# 19          transaction  0009655768c64bdeb2e877511632db8f   18.41     NaN
# 20       offer received  00116118485d4dfda04fdbaba9a87b5c     NaN     NaN
# 21         offer viewed  00116118485d4dfda04fdbaba9a87b5c     NaN     NaN
# 22          transaction  00116118485d4dfda04fdbaba9a87b5c    0.70     NaN
# 23          transaction  00116118485d4dfda04fdbaba9a87b5c    0.20     NaN
# 24          transaction  00116118485d4dfda04fdbaba9a87b5c    3.19     NaN
# 25       offer received  00116118485d4dfda04fdbaba9a87b5c     NaN     NaN
# 26         offer viewed  00116118485d4dfda04fdbaba9a87b5c     NaN     NaN
# 27       offer received  0011e0d4e6b944f998e987f904e8c1e5     NaN     NaN
# 28         offer viewed  0011e0d4e6b944f998e987f904e8c1e5     NaN     NaN
# 8       [web, email, mobile, social]           5           bogo       5
# 9       [web, email, mobile, social]          10       discount       2
# 11      [web, email, mobile, social]          10       discount       2
# 10      [web, email, mobile, social]           5           bogo       5
# 12      [web, email, mobile, social]          10       discount       2
# 13      [web, email, mobile, social]          10       discount       2
# 16              [web, email, mobile]          10       discount       2
# 14              [web, email, mobile]          10       discount       2
# 15      [web, email, mobile, social]          10       discount       2
# 17      [web, email, mobile, social]          10       discount       2
# 18      [web, email, mobile, social]          10       discount       2
# 19      [web, email, mobile, social]          10       discount       2
# 20      [web, email, mobile, social]           5           bogo       5
# 21      [web, email, mobile, social]           5           bogo       5
# 22      [web, email, mobile, social]           5           bogo       5
# 23      [web, email, mobile, social]           5           bogo       5
# 24      [web, email, mobile, social]           5           bogo       5
# 25      [web, email, mobile, social]           5           bogo       5
# 26      [web, email, mobile, social]           5           bogo       5
# 27              [web, email, mobile]           0  informational       0
# 28              [web, email, mobile]           0  informational       0
# 29              [web, email, mobile]           0  informational       0
# ...                              ...         ...            ...     ...
# 306503  [web, email, mobile, social]          10       discount       2
# 306505  [web, email, mobile, social]          10       discount       2
# 306506  [web, email, mobile, social]          10       discount       2
# 306507                  [web, email]          20       discount       5
# 306508                  [web, email]          20       discount       5
# 306510                  [web, email]          20       discount       5
# 306509                  [web, email]          20       discount       5
# 306511                  [web, email]          20       discount       5
# 306512                  [web, email]          20       discount       5
# 306513                  [web, email]          20       discount       5
# 306514                  [web, email]          20       discount       5
# 306515          [web, email, mobile]          10       discount       2
# 306516          [web, email, mobile]          10       discount       2
# 306518          [web, email, mobile]          10       discount       2
# 306517          [web, email, mobile]          10       discount       2
# 306519          [web, email, mobile]          10       discount       2
# 306522          [web, email, mobile]          10       discount       2
# 306520          [web, email, mobile]          10       discount       2
# 306521          [web, email, mobile]          10       discount       2
# 306523          [web, email, mobile]          10       discount       2
# 306526          [web, email, mobile]           5           bogo       5
# 306524          [web, email, mobile]           5           bogo       5
# 306525          [web, email, mobile]          10       discount       2
# 306527          [web, email, mobile]           5           bogo       5
# 306530          [web, email, mobile]          10       discount       2
# 306528          [web, email, mobile]          10       discount       2
# 306529          [web, email, mobile]           5           bogo       5
# 306531          [web, email, mobile]          10       discount       2
# 306532          [web, email, mobile]          10       discount       2
# 306533          [web, email, mobile]          10       discount       2
#
#         duration                 offer_id_previous  valid_completed  \
# 0            3.0                               NaN              NaN
# 1            3.0                               NaN              0.0
# 2            3.0  5a8bc65990b245e5a138643cd4eb9837              1.0
# 3            4.0                               NaN              NaN
# 4            4.0                               NaN              0.0
# 5            5.0                               NaN              NaN
# 7            5.0                               NaN              0.0
# 6            4.0  3f207df678b143eea3cee63160fa8bed              1.0
# 8            5.0  f19421c1d4aa40978ebb69ca19b0e20d              1.0
# 9           10.0                               NaN              NaN
# 11          10.0                               NaN              0.0
# 10           5.0  f19421c1d4aa40978ebb69ca19b0e20d              1.0
# 12          10.0  fafdcd668e3743c1bb461111dcafc2a4              1.0
# 13          10.0  fafdcd668e3743c1bb461111dcafc2a4              1.0
# 16           7.0                               NaN              0.0
# 14           7.0                               NaN              NaN
# 15          10.0  fafdcd668e3743c1bb461111dcafc2a4              1.0
# 17          10.0  fafdcd668e3743c1bb461111dcafc2a4              1.0
# 18          10.0  fafdcd668e3743c1bb461111dcafc2a4              1.0
# 19          10.0  fafdcd668e3743c1bb461111dcafc2a4              1.0
# 20           5.0                               NaN              NaN
# 21           5.0                               NaN              0.0
# 22           5.0  f19421c1d4aa40978ebb69ca19b0e20d              1.0
# 23           5.0  f19421c1d4aa40978ebb69ca19b0e20d              1.0
# 24           5.0  f19421c1d4aa40978ebb69ca19b0e20d              1.0
# 25           5.0                               NaN              NaN
# 26           5.0  f19421c1d4aa40978ebb69ca19b0e20d              1.0
# 27           4.0                               NaN              NaN
# 28           4.0                               NaN              0.0
# 29           4.0  3f207df678b143eea3cee63160fa8bed              1.0
# ...          ...                               ...              ...
# 306503      10.0  fafdcd668e3743c1bb461111dcafc2a4              1.0
# 306505      10.0  fafdcd668e3743c1bb461111dcafc2a4              1.0
# 306506      10.0  fafdcd668e3743c1bb461111dcafc2a4              1.0
# 306507      10.0                               NaN              NaN
# 306508      10.0                               NaN              0.0
# 306510      10.0  0b1e1539f2cc45b7b9fa7c272da2e1d7              1.0
# 306509      10.0  0b1e1539f2cc45b7b9fa7c272da2e1d7              1.0
# 306511      10.0  0b1e1539f2cc45b7b9fa7c272da2e1d7              1.0
# 306512      10.0  0b1e1539f2cc45b7b9fa7c272da2e1d7              1.0
# 306513      10.0  0b1e1539f2cc45b7b9fa7c272da2e1d7              1.0
# 306514      10.0  0b1e1539f2cc45b7b9fa7c272da2e1d7              1.0
# 306515       7.0                               NaN              NaN
# 306516       7.0                               NaN              0.0
# 306518       7.0  2906b810c7d4411798c6938adc9daaa5              1.0
# 306517       7.0  2906b810c7d4411798c6938adc9daaa5              1.0
# 306519       7.0                               NaN              NaN
# 306522       7.0  2906b810c7d4411798c6938adc9daaa5              1.0
# 306520       7.0  2906b810c7d4411798c6938adc9daaa5              1.0
# 306521       7.0  2906b810c7d4411798c6938adc9daaa5              1.0
# 306523       7.0  2906b810c7d4411798c6938adc9daaa5              1.0
# 306526       7.0                               NaN              0.0
# 306524       7.0                               NaN              NaN
# 306525       7.0  2906b810c7d4411798c6938adc9daaa5              1.0
# 306527       7.0  9b98b8c7a33c4b65b9aebfe6a799e6d9              1.0
# 306530       7.0  2906b810c7d4411798c6938adc9daaa5              1.0
# 306528       7.0                               NaN              NaN
# 306529       7.0  9b98b8c7a33c4b65b9aebfe6a799e6d9              1.0
# 306531       7.0  2906b810c7d4411798c6938adc9daaa5              1.0
# 306532       7.0  2906b810c7d4411798c6938adc9daaa5              1.0
# 306533       7.0  2906b810c7d4411798c6938adc9daaa5              1.0
#
#         diff_info  diff_bogo  diff_discount  valid_completed_duration
# 0             NaN        NaN            NaN                       NaN
# 1             NaN        NaN            NaN                       NaN
# 2            2.50        NaN            NaN                       1.0
# 3             NaN        NaN            NaN                       NaN
# 4             NaN        NaN            NaN                       NaN
# 5             NaN        NaN            NaN                       NaN
# 7             NaN       0.25            NaN                       1.0
# 6            3.25        NaN            NaN                       1.0
# 8             NaN        NaN            NaN                       NaN
# 9             NaN        NaN            NaN                       NaN
# 11            NaN        NaN           1.00                       1.0
# 10            NaN        NaN            NaN                       NaN
# 12            NaN        NaN            NaN                       NaN
# 13            NaN        NaN            NaN                       NaN
# 16            NaN        NaN            NaN                       NaN
# 14            NaN        NaN           0.00                       1.0
# 15            NaN        NaN            NaN                       NaN
# 17            NaN        NaN            NaN                       NaN
# 18            NaN        NaN            NaN                       NaN
# 19            NaN        NaN            NaN                       NaN
# 20            NaN        NaN            NaN                       NaN
# 21            NaN        NaN            NaN                       NaN
# 22            NaN        NaN            NaN                       NaN
# 23            NaN        NaN            NaN                       NaN
# 24            NaN        NaN            NaN                       NaN
# 25            NaN      17.00            NaN                       NaN
# 26            NaN        NaN            NaN                       NaN
# 27            NaN        NaN            NaN                       NaN
# 28            NaN        NaN            NaN                       NaN
# 29           5.50        NaN            NaN                       NaN
# ...           ...        ...            ...                       ...
# 306503        NaN        NaN            NaN                       NaN
# 306505        NaN        NaN            NaN                       NaN
# 306506        NaN        NaN            NaN                       NaN
# 306507        NaN        NaN            NaN                       NaN
# 306508        NaN        NaN            NaN                       NaN
# 306510        NaN        NaN           1.25                       1.0
# 306509        NaN        NaN            NaN                       NaN
# 306511        NaN        NaN            NaN                       NaN
# 306512        NaN        NaN            NaN                       NaN
# 306513        NaN        NaN            NaN                       NaN
# 306514        NaN        NaN            NaN                       NaN
# 306515        NaN        NaN            NaN                       NaN
# 306516        NaN        NaN            NaN                       NaN
# 306518        NaN        NaN           2.00                       1.0
# 306517        NaN        NaN            NaN                       NaN
# 306519        NaN        NaN           1.00                       1.0
# 306522        NaN        NaN           0.25                       1.0
# 306520        NaN        NaN            NaN                       NaN
# 306521        NaN        NaN            NaN                       NaN
# 306523        NaN        NaN            NaN                       NaN
# 306526        NaN        NaN            NaN                       NaN
# 306524        NaN       0.00            NaN                       1.0
# 306525        NaN        NaN            NaN                       NaN
# 306527        NaN        NaN            NaN                       NaN
# 306530        NaN        NaN           6.75                       1.0
# 306528        NaN        NaN           0.00                       1.0
# 306529        NaN        NaN            NaN                       NaN
# 306531        NaN        NaN            NaN                       NaN
# 306532        NaN        NaN            NaN                       NaN
# 306533        NaN        NaN            NaN                       NaN
#
# [306534 rows x 17 columns]

# %%
transactions_clean2[(transactions_clean2['event']=='offer completed') | (transactions_clean2['event']=='offer viewed') | (transactions_clean2['event']=='transactions')]
# Out:
#                   event                            person  amount  reward  \
# 1          offer viewed  0009655768c64bdeb2e877511632db8f     NaN     NaN
# 4          offer viewed  0009655768c64bdeb2e877511632db8f     NaN     NaN
# 7       offer completed  0009655768c64bdeb2e877511632db8f     NaN     5.0
# 8          offer viewed  0009655768c64bdeb2e877511632db8f     NaN     NaN
# 11      offer completed  0009655768c64bdeb2e877511632db8f     NaN     2.0
9b98b8c7a33c4b65b9aebfe6a799e6d9
# 85          25.00  9b98b8c7a33c4b65b9aebfe6a799e6d9
# ...           ...                               ...
# 306445      22.00  2906b810c7d4411798c6938adc9daaa5
# 306446      22.50  5a8bc65990b245e5a138643cd4eb9837
# 306451       1.00  fafdcd668e3743c1bb461111dcafc2a4
# 306454       7.50  4d5c57ea9a6940dd891ad53e9dbe8da0
# 306456       8.00  fafdcd668e3743c1bb461111dcafc2a4
# 306459      17.25  ae264e3637204a6fb9bb56bc8210ddfd
# 306461      21.75  fafdcd668e3743c1bb461111dcafc2a4
# 306466      24.75  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 306465      24.75  fafdcd668e3743c1bb461111dcafc2a4
# 306471      18.00  fafdcd668e3743c1bb461111dcafc2a4
# 306477      27.50  4d5c57ea9a6940dd891ad53e9dbe8da0
# 306479       0.25  f19421c1d4aa40978ebb69ca19b0e20d
# 306481       1.50  f19421c1d4aa40978ebb69ca19b0e20d
# 306486       7.00  5a8bc65990b245e5a138643cd4eb9837
# 306492      21.25  f19421c1d4aa40978ebb69ca19b0e20d
# 306494      21.50  f19421c1d4aa40978ebb69ca19b0e20d
# 306498      24.50  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 306499      27.75  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 306502       0.25  fafdcd668e3743c1bb461111dcafc2a4
# 306504       2.50  fafdcd668e3743c1bb461111dcafc2a4
# 306508       7.25  0b1e1539f2cc45b7b9fa7c272da2e1d7
# 306510       8.25  0b1e1539f2cc45b7b9fa7c272da2e1d7
# 306516      14.75  2906b810c7d4411798c6938adc9daaa5
# 306518      16.00  2906b810c7d4411798c6938adc9daaa5
# 306522      17.25  2906b810c7d4411798c6938adc9daaa5
# 306520      17.25  2906b810c7d4411798c6938adc9daaa5
# 306526      21.00  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 306527      22.25  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 306530      24.00  2906b810c7d4411798c6938adc9daaa5
# 306531      24.25  2906b810c7d4411798c6938adc9daaa5
#
#                             channels  difficulty     offer_type  reward  \
# 1            [email, mobile, social]           0  informational       0
# 4               [web, email, mobile]           0  informational       0
# 7       [web, email, mobile, social]           5           bogo       5
# 8       [web, email, mobile, social]           5           bogo       5
# 11      [web, email, mobile, social]          10       discount       2
# 12      [web, email, mobile, social]          10       discount       2
# 16              [web, email, mobile]          10       discount       2
# 21      [web, email, mobile, social]           5           bogo       5
# 26      [web, email, mobile, social]           5           bogo       5
# 28              [web, email, mobile]           0  informational       0
# 31      [web, email, mobile, social]           7       discount       3
# 33      [web, email, mobile, social]           7       discount       3
# 35           [email, mobile, social]           0  informational       0
# 37                      [web, email]          20       discount       5
# 39              [web, email, mobile]           5           bogo       5
# 41                      [web, email]          20       discount       5
# 42              [web, email, mobile]           5           bogo       5
# 46      [web, email, mobile, social]          10       discount       2
# 48      [web, email, mobile, social]          10       discount       2
# 55      [web, email, mobile, social]          10           bogo      10
# 59      [web, email, mobile, social]          10           bogo      10
# 58      [web, email, mobile, social]          10       discount       2
# 61           [email, mobile, social]           0  informational       0
# 66      [web, email, mobile, social]           7       discount       3
# 68      [web, email, mobile, social]           7       discount       3
# 73      [web, email, mobile, social]           5           bogo       5
# 75      [web, email, mobile, social]           5           bogo       5
# 77           [email, mobile, social]           0  informational       0
# 83              [web, email, mobile]           5           bogo       5
# 85              [web, email, mobile]           5           bogo       5
# ...                              ...         ...            ...     ...
# 306445          [web, email, mobile]          10       discount       2
# 306446       [email, mobile, social]           0  informational       0
# 306451  [web, email, mobile, social]          10       discount       2
# 306454  [web, email, mobile, social]          10           bogo      10
# 306456  [web, email, mobile, social]          10       discount       2
# 306459       [email, mobile, social]          10           bogo      10
# 306461  [web, email, mobile, social]          10       discount       2
# 306466          [web, email, mobile]           5           bogo       5
# 306465  [web, email, mobile, social]          10       discount       2
# 306471  [web, email, mobile, social]          10       discount       2
# 306477  [web, email, mobile, social]          10           bogo      10
# 306479  [web, email, mobile, social]           5           bogo       5
# 306481  [web, email, mobile, social]           5           bogo       5
# 306486       [email, mobile, social]           0  informational       0
# 306492  [web, email, mobile, social]           5           bogo       5
# 306494  [web, email, mobile, social]           5           bogo       5
# 306498          [web, email, mobile]           5           bogo       5
# 306499          [web, email, mobile]           5           bogo       5
# 306502  [web, email, mobile, social]          10       discount       2
# 306504  [web, email, mobile, social]          10       discount       2
# 306508                  [web, email]          20       discount       5
# 306510                  [web, email]          20       discount       5
# 306516          [web, email, mobile]          10       discount       2
# 306518          [web, email, mobile]          10       discount       2
# 306522          [web, email, mobile]          10       discount       2
# 306520          [web, email, mobile]          10       discount       2
# 306526          [web, email, mobile]           5           bogo       5
# 306527          [web, email, mobile]           5           bogo       5
# 306530          [web, email, mobile]          10       discount       2
# 306531          [web, email, mobile]          10       discount       2
#
#         duration                 offer_id_previous  valid_completed  \
# 1            3.0                               NaN              0.0
# 4            4.0                               NaN              0.0
# 7            5.0                               NaN              0.0
# 8            5.0  f19421c1d4aa40978ebb69ca19b0e20d              1.0
# 11          10.0                               NaN              0.0
# 12          10.0  fafdcd668e3743c1bb461111dcafc2a4              1.0
# 16           7.0                               NaN              0.0
# 21           5.0                               NaN              0.0
# 26           5.0  f19421c1d4aa40978ebb69ca19b0e20d              1.0
# 28           4.0                               NaN              0.0
# 31           7.0                               NaN              0.0
# 33           7.0  2298d6c36e964ae4a3e7e9706d1fb8c2              1.0
# 35           3.0                               NaN              0.0
# 37          10.0                               NaN              0.0
# 39           7.0                               NaN              0.0
# 41          10.0  0b1e1539f2cc45b7b9fa7c272da2e1d7              1.0
# 42           7.0  9b98b8c7a33c4b65b9aebfe6a799e6d9              1.0
# 46          10.0                               NaN              0.0
# 48          10.0  fafdcd668e3743c1bb461111dcafc2a4              1.0
# 55           5.0                               NaN              0.0
# 59           5.0  4d5c57ea9a6940dd891ad53e9dbe8da0              1.0
# 58          10.0  fafdcd668e3743c1bb461111dcafc2a4              1.0
# 61           3.0                               NaN              0.0
# 66           7.0                               NaN              0.0
# 68           7.0  2298d6c36e964ae4a3e7e9706d1fb8c2              1.0
# 73           5.0                               NaN              0.0
# 75           5.0  f19421c1d4aa40978ebb69ca19b0e20d              1.0
# 77           3.0  5a8bc65990b245e5a138643cd4eb9837              1.0
# 83           7.0                               NaN              0.0
# 85           7.0  9b98b8c7a33c4b65b9aebfe6a799e6d9              1.0
# ...          ...                               ...              ...
# 306445       7.0                               NaN              0.0
# 306446       3.0                               NaN              0.0
# 306451      10.0                               NaN              0.0
# 306454       5.0                               NaN              0.0
# 306456      10.0  fafdcd668e3743c1bb461111dcafc2a4              1.0
# 306459       7.0                               NaN              0.0
# 306461      10.0  fafdcd668e3743c1bb461111dcafc2a4              1.0
# 306466       7.0                               NaN              0.0
# 306465      10.0  fafdcd668e3743c1bb461111dcafc2a4              1.0
# 306471      10.0  fafdcd668e3743c1bb461111dcafc2a4              1.0
# 306477       5.0                               NaN              0.0
# 306479       5.0                               NaN              0.0
# 306481       5.0  f19421c1d4aa40978ebb69ca19b0e20d              1.0
# 306486       3.0                               NaN              0.0
# 306492       5.0  f19421c1d4aa40978ebb69ca19b0e20d              1.0
# 306494       5.0  f19421c1d4aa40978ebb69ca19b0e20d              1.0
# 306498       7.0                               NaN              0.0
# 306499       7.0  9b98b8c7a33c4b65b9aebfe6a799e6d9              1.0
# 306502      10.0                               NaN              0.0
# 306504      10.0  fafdcd668e3743c1bb461111dcafc2a4              1.0
# 306508      10.0                               NaN              0.0
# 306510      10.0  0b1e1539f2cc45b7b9fa7c272da2e1d7              1.0
# 306516       7.0                               NaN              0.0
# 306518       7.0  2906b810c7d4411798c6938adc9daaa5              1.0
# 306522       7.0  2906b810c7d4411798c6938adc9daaa5              1.0
# 306520       7.0  2906b810c7d4411798c6938adc9daaa5              1.0
# 306526       7.0                               NaN              0.0
# 306527       7.0  9b98b8c7a33c4b65b9aebfe6a799e6d9              1.0
# 306530       7.0  2906b810c7d4411798c6938adc9daaa5              1.0
# 306531       7.0  2906b810c7d4411798c6938adc9daaa5              1.0
#
#         diff_info  diff_bogo  diff_discount  valid_completed_duration
# 1             NaN        NaN            NaN                       NaN
# 4             NaN        NaN            NaN                       NaN
# 7             NaN       0.25            NaN                       1.0
# 8             NaN        NaN            NaN                       NaN
# 11            NaN        NaN           1.00                       1.0
# 12            NaN        NaN            NaN                       NaN
# 16            NaN        NaN            NaN                       NaN
# 21            NaN        NaN            NaN                       NaN
# 26            NaN        NaN            NaN                       NaN
# 28            NaN        NaN            NaN                       NaN
# 31            NaN        NaN            NaN                       NaN
# 33            NaN        NaN           3.50                       1.0
# 35            NaN        NaN            NaN                       NaN
# 37            NaN        NaN            NaN                       NaN
# 39            NaN        NaN            NaN                       NaN
# 41            NaN        NaN           7.00                       1.0
# 42            NaN       3.00            NaN                       1.0
# 46            NaN        NaN            NaN                       NaN
# 48            NaN        NaN           2.25                       1.0
# 55            NaN        NaN            NaN                       NaN
# 59            NaN       4.25            NaN                       1.0
# 58            NaN        NaN           7.25                       1.0
# 61            NaN        NaN            NaN                       NaN
# 66            NaN        NaN            NaN                       NaN
# 68            NaN        NaN           2.25                       1.0
# 73            NaN        NaN            NaN                       NaN
# 75            NaN       1.75            NaN                       1.0
# 77            NaN        NaN            NaN                       NaN
# 83            NaN        NaN            NaN                       NaN
# 85            NaN       4.00            NaN                       1.0
# ...           ...        ...            ...                       ...
# 306445        NaN        NaN           5.00                       1.0
# 306446        NaN        NaN            NaN                       NaN
# 306451        NaN        NaN            NaN                       NaN
# 306454        NaN        NaN            NaN                       NaN
# 306456        NaN        NaN           8.00                       1.0
# 306459        NaN        NaN            NaN                       NaN
# 306461        NaN        NaN            NaN                       NaN
# 306466        NaN       0.75            NaN                       1.0
# 306465        NaN        NaN           3.75                       1.0
# 306471        NaN        NaN            NaN                       NaN
# 306477        NaN        NaN            NaN                       NaN
# 306479        NaN        NaN            NaN                       NaN
# 306481        NaN       1.50            NaN                       1.0
# 306486        NaN        NaN            NaN                       NaN
# 306492        NaN        NaN            NaN                       NaN
# 306494        NaN       4.50            NaN                       1.0
# 306498        NaN       0.50            NaN                       1.0
# 306499        NaN        NaN            NaN                       NaN
# 306502        NaN        NaN            NaN                       NaN
# 306504        NaN        NaN           2.50                       1.0
# 306508        NaN        NaN            NaN                       NaN
# 306510        NaN        NaN           1.25                       1.0
# 306516        NaN        NaN            NaN                       NaN
# 306518        NaN        NaN           2.00                       1.0
# 306522        NaN        NaN           0.25                       1.0
# 306520        NaN        NaN            NaN                       NaN
# 306526        NaN        NaN            NaN                       NaN
# 306527        NaN        NaN            NaN                       NaN
# 306530        NaN        NaN           6.75                       1.0
# 306531        NaN        NaN            NaN                       NaN
#
# [91304 rows x 17 columns]

# %%
#classes are relatively balanced except for informational offers

# %%
#get people who purchased but did not receive any offers
df3=transcript[np.logical_not(transcript['person'].isin(df2['person']))]

# %%
df3.head()

# %%
profile.rename(columns={'id':'person'},inplace=True)

# %%
no_offers=df3.merge(profile,how='left',on='person')

# %%
no_offers.drop(['value','reward','offer_id','event','time'],axis=1,inplace=True)

# %%
#check for missing values
offers['gender'].isnull().sum()/len(offers)

# %%
offers['income'].isnull().sum()/len(offers)

# %%
offers['gender'][offers['offer_type']=='bogo'].isnull().sum()/len(offers[offers['offer_type']=='bogo'])

# %%
offers['gender'][offers['offer_type']=='discount'].isnull().sum()/len(offers[offers['offer_type']=='discount'])

# %%
offers['gender'][offers['offer_type']=='informational'].isnull().sum()/len(offers[offers['offer_type']=='informational'])

# %%
len(offers[offers['offer_type']=='informational'])/len(offers)

# %%
len(offers[offers['offer_type']=='bogo'])/len(offers)

# %%
len(offers[offers['offer_type']=='discount'])/len(offers)

# %%
channels = offers['channels'].apply(pd.Series)

# %%
channels = channels.rename(columns={0:'web',1:'email',2:'mobile',3:'social'})

# %%
offers=pd.concat([offers[:], channels[:]], axis=1)

# %%
def rename(col_name,df=offers):
    df[col_name]=np.where(df[col_name]==col_name,1,0)
    return df

# %%
rename('web')
rename('email')
rename('mobile')
rename('social')

# %%
drop_cols('channels',offers);

# %%
offers=pd.concat([offers[:],pd.get_dummies(offers['offer_type'],prefix='offer_type')],axis=1)

# %%
drop_cols('offer_type',offers);

# %%
offers['year']=pd.Series([int(str(x)[:4]) for x in offers['became_member_on']])

# %%
offers['month']=pd.Series([int(str(x)[-3]) for x in offers['became_member_on']])

# %%
offers['day']=pd.Series([int(str(x)[-2:]) for x in offers['became_member_on']])

# %%
def drop_cols(drop_cols,df=offers):
    df.drop(drop_cols,axis=1,inplace=True)
    return df

# %%
drop_cols('became_member_on',offers);

# %%
offers.loc[offers['year'] == 2018, 'membership_tenure_days'] = (30*offers['month'])+offers['day']
offers.loc[offers['year'] != 2018, 'membership_tenure_days'] = ((2018-offers['year'])*365)+(30*offers['month'])+offers['day']

# %%
drop_cols(['year','month','day'],offers);

# %%
offers['age'].unique()

# %%
offers['age'].hist()

# %%
offers.isnull().sum().sort_values(ascending=False)

# %%
offers[['age','gender','income']][offers['income'].isnull()].head()
#we can see that the age is not useful in the cases where gender and income are null. Hence, can drop these values

# %%
offers.dropna(axis=0,inplace=True)

# %%
offers=pd.concat([offers[:],pd.get_dummies(offers['gender'],prefix='gender')],axis=1)

# %%
drop_cols('gender',offers);

# %%
offers.columns

# %%
offers['person'].nunique()

# %%
no_offers.nunique()

# %% [markdown]
# 4 individual models - determine demographic types that would respond to each type of offer effectively. 3 types of offers, and one type which does not purchase any at all (only 20 records).
#
# Overall multiclass model - only for effective offers.
# Overall model - determine how much someone would spend depending on offer type and demographics.
#
# All in all, 6 total models.
#
# There may be people who viewed and completed offers (effective offers) but no transaction associated.

# %%
offers.head()

# %%
len(offers[offers['effective_offer']==1])/len(offers)

# %%
offers_bogo=offers[offers['offer_type_bogo']==1].copy()
offers_discount=offers[offers['offer_type_discount']==1].copy()
offers_info=offers[offers['offer_type_informational']==1].copy()

# %%
offers.loc[offers['offer_type_bogo'] == 1, 'type'] =0
offers.loc[offers['offer_type_discount'] == 1, 'type'] =1
offers.loc[offers['offer_type_informational'] == 1, 'type'] =2

# %% [markdown]
# Model 1: Determine what are the drivers of effectiveness of bogo type offers

# %%
def data_prep(df):
    drop_cols_offer=['type','amount','offer_type_discount','offer_type_informational','offer_type_bogo']
    drop_cols(drop_cols_offer,df)
    #drop duplicates
    df.drop_duplicates(subset='person',inplace=True)
    # Split the data into features and target label
    drop_cols_offer=['person','effective_offer']
    target = df['effective_offer']
    features = drop_cols(drop_cols_offer,df)
    return features,target

# %%
def model_pipeline(df):
    features,target=data_prep(df)
    #split into training and test sets
    X_train, X_test, y_train, y_test = train_test_split(features,target, 
                                                        test_size=0.20, 
                                                        random_state=42)
    #fit and transform training data
    scaler=StandardScaler()
    X_train=scaler.fit_transform(X_train)

    #transform test data
    X_test=scaler.transform(X_test)
    return X_train,X_test,y_train, y_test

# %%
X_train, X_test, y_train, y_test=model_pipeline(offers_bogo)

# %%
def train_predict(learner, sample_size, X_train, y_train, X_test, y_test): 
    '''
    inputs:
       - learner: the learning algorithm to be trained and predicted on
       - sample_size: the size of samples (number) to be drawn from training set
       - X_train: features training set
       - y_train: review_scores_rating training set
       - X_test: features testing set
       - y_test: review_scores_rating testing set
    '''
    results = {}
    
    #Fit the learner to the training data and get training time
    start = time() 
    learner = learner.fit(X_train[:sample_size], y_train[:sample_size])
    end = time() 
    results['train_time'] = end-start
    
    # Get predictions on the test set(X_test), then get predictions on first 300 training samples
    start = time() 
    predictions_test = learner.predict(X_test)
    predictions_train = learner.predict(X_train[:300])
    end = time() 
    
    # Calculate the total prediction time
    results['pred_time'] = end-start
    
    #Compute accuracy on the first 300 training samples
    results['mse_train'] = mean_squared_error(y_train[:300],predictions_train)
    
    #Compute accuracy on test set
    results['mse_test'] = mean_squared_error(y_test,predictions_test)
    
    print("{} trained on {} samples.".format(learner.__class__.__name__, sample_size))
    print("MSE_train: %.4f" % results['mse_train'])
    print("MSE_test: %.4f" % results['mse_test'])
    print("Training score:%.4f" % learner.score(X_train,y_train))
    print("Test score:%.4f" % learner.score(X_test,y_test))
    return results

# %%
X_train, X_test, y_train, y_test=model_pipeline(offers_discount)

# %%
def run_model(clf1,clf2):
    # Calculate the number of samples for 1% and 100% of the training data
    samples_100 = len(y_train)
    samples_1 = int(0.01*len(y_train))

    # Collect results on the learners
    results = {}
    for clf in [clf1, clf2]:
        clf_name = clf.__class__.__name__
        results[clf_name] = {}
        for i, samples in enumerate([samples_1, samples_100]):
            results[clf_name][i] = \
            train_predict(clf, samples, X_train, y_train, X_test, y_test)

# %%
#Initialize the model
clf1 = svm.SVC(C= 0.1, gamma= 0.001, kernel= 'rbf')
clf2 = RandomForestClassifier(max_depth= 5, max_features= 'auto',min_samples_split= 10,n_estimators=20,min_samples_leaf=10)

run_model(clf1,clf2)

# %%
#Initialize the model
clf1 = LogisticRegression(penalty='l1')
clf2 = RandomForestClassifier(max_depth= 10, max_features= 'auto',min_samples_split= 20,n_estimators=20,min_samples_leaf=10)
run_model(clf1,clf2)

# %%
#Initialize the model
clf1 = LogisticRegression(penalty='l1')
clf2 = AdaBoostClassifier(base_estimator=DecisionTreeClassifier(criterion='entropy',max_depth=10,random_state=2,min_samples_split=100),n_estimators=10)
run_model(clf1,clf2)

# %%
#Initialize the model
clf1 = LogisticRegression(penalty='l1')
clf2 = DecisionTreeClassifier(criterion='entropy',max_depth=5,random_state=2,min_samples_split=90,min_samples_leaf=50)

run_model(clf1,clf2)

# %%
#Initialize the model
clf1 = LogisticRegression(penalty='l2',C=0.8)
clf2 = XGBClassifier(max_depth=6,n_estimators=15,gamma=0.01,seed=2,learning_rate=0.2)

run_model(clf1,clf2)

# %%
X_train, X_test, y_train, y_test=model_pipeline(offers_info)

# %%
#Initialize the model
clf1 = svm.SVC(C= 0.1, gamma= 0.001, kernel= 'rbf')
clf2 = RandomForestClassifier(max_depth= 5, max_features= 'auto',min_samples_split= 10,n_estimators=20,min_samples_leaf=10)

run_model(clf1,clf2)

# %%
# def svc_param_selection(X, y):
#     Cs = [0.001, 0.01, 0.1, 1, 10]
#     gammas = [0.001, 0.01, 0.1, 1]
#     kernel=['poly','rbf','linear','sigmoid']
#     param_grid = {'C': Cs, 'gamma' : gammas,'kernel': kernel}
#     grid_search = GridSearchCV(svm.SVC(random_state=2), param_grid)
#     grid_search.fit(X, y)
#     grid_search.best_params_
#     return grid_search.best_params_

# %%
# def rand_forest_param_selection(X,y):
#     param_grid={'max_features': ['auto', 'sqrt'],
#                 'max_depth' : [5,10],
#                 'n_estimators': [20, 30, 40],
#                 'min_samples_split': [2, 10, 20],
#                 }
#     grid_search = GridSearchCV(RandomForestClassifier(random_state=2), param_grid)
#     grid_search.fit(X, y)
#     grid_search.best_params_
#     return grid_search.best_params_
# rand_forest_param_selection(X_train[:samples_1], y_train[:samples_1])
